# %%
import sys
from pathlib import Path

sys.path.append(str(Path("..").resolve()))

# %%
# %pip install pandas matplotlib seaborn --quiet

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from src.data_loader import load_movies, load_ratings
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load the data (ensure cell 1 with imports has been executed first)
movies = load_movies()
ratings = load_ratings()

# %%
print("Movies shape:", movies.shape)
print("Ratings shape:", ratings.shape)

ratings.describe()
# Out:
# Movies shape: (87585, 3)
# Ratings shape: (4800031, 4)
#              userId       movieId        rating     timestamp
# count  4.800031e+06  4.800031e+06  4.800031e+06  4.800031e+06
# mean   1.002742e+05  2.934578e+04  3.540203e+00  1.275230e+09
# std    5.794910e+04  5.097387e+04  1.059335e+00  2.561417e+08
# min    1.000000e+00  1.000000e+00  5.000000e-01  8.228736e+08
# 25%    5.005300e+04  1.233000e+03  3.000000e+00  1.051052e+09
# 50%    1.002970e+05  3.452000e+03  3.500000e+00  1.272612e+09
# 75%    1.504510e+05  4.439700e+04  4.000000e+00  1.503065e+09
# max    2.009480e+05  2.927090e+05  5.000000e+00  1.697164e+09

# %%
plt.figure(figsize=(6,4))
sns.histplot(ratings["rating"], bins=10)
plt.title("Rating Distribution")
plt.xlabel("Rating")
plt.ylabel("Count")
plt.show()

# %%
ratings_per_user = ratings.groupby("userId").size()

plt.figure(figsize=(6,4))
sns.histplot(ratings_per_user, bins=50)
plt.title("Ratings per User")
plt.show()
